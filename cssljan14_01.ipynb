# %% [markdown]
# <a href="https://colab.research.google.com/github/mahimahubz42/computationalstatscourse26/blob/main/cssljan14_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
ad = [1,3,5,7,13,17]
sales = [12,14,18,20,22]
plt.plot(ad, sales)
